# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.99439428, 0.80094001, 0.6072945 , 0.30021993, 0.86843352,
#        0.65448429, 0.56537284, 0.93019818, 0.64228174, 0.28871754,
#        0.17849082, 0.49555738, 0.16220063, 0.81511472, 0.31057824,
#        0.80757229, 0.33552685, 0.47977501, 0.10431931, 0.40144193,
#        0.10905712, 0.89260206, 0.46180226, 0.3916302 , 0.33336511,
#        0.25576556, 0.71674254, 0.01348649, 0.56982838, 0.57260724,
#        0.64604765, 0.04615143, 0.83035231, 0.53207247, 0.34942978,
#        0.62963831, 0.82220472, 0.03390221, 0.7599935 , 0.67277931,
#        0.25348393, 0.27336396, 0.8675593 , 0.55300557, 0.28765285,
#        0.1720986 , 0.58101067, 0.44093296, 0.981976  , 0.69994691])

# %%
y
# Out:
# array([0.77919509, 0.03042532, 0.53797429, 0.27397194, 0.95103103,
#        0.77832661, 0.10409846, 0.74323245, 0.54159566, 0.65184549,
#        0.33046322, 0.67530215, 0.06071268, 0.82847562, 0.23151547,
#        0.43025142, 0.68301599, 0.08354767, 0.67446367, 0.44413595,
#        0.4454396 , 0.24818323, 0.76523734, 0.16557155, 0.96062954,
#        0.5281491 , 0.09090382, 0.61290598, 0.04100367, 0.90076131,
#        0.37181082, 0.45774495, 0.96416389, 0.0102385 , 0.57728128,
#        0.7911307 , 0.00804486, 0.81449229, 0.3416583 , 0.42966798,
#        0.23536581, 0.79318762, 0.39834853, 0.5920455 , 0.17637313,
#        0.30028806, 0.77443738, 0.74528776, 0.4357744 , 0.19440245])

# %%
plt.scatter(x,y)

# %%
plt.figure(figsize=(6,2))
plt.scatter(x,y,c = "b",alpha = 0.99,marker="+")
plt.xlabel("This is my x axis -->")
plt.ylabel("This is my y axis -->")
plt.title("This is my x vs y")
plt.grid()

# %%
x = np.linspace(1,10,100)

# %%
y = np.sin(x)

# %%
x
# Out:
# array([ 1.        ,  1.09090909,  1.18181818,  1.27272727,  1.36363636,
#         1.45454545,  1.54545455,  1.63636364,  1.72727273,  1.81818182,
#         1.90909091,  2.        ,  2.09090909,  2.18181818,  2.27272727,
#         2.36363636,  2.45454545,  2.54545455,  2.63636364,  2.72727273,
#         2.81818182,  2.90909091,  3.        ,  3.09090909,  3.18181818,
#         3.27272727,  3.36363636,  3.45454545,  3.54545455,  3.63636364,
#         3.72727273,  3.81818182,  3.90909091,  4.        ,  4.09090909,
#         4.18181818,  4.27272727,  4.36363636,  4.45454545,  4.54545455,
#         4.63636364,  4.72727273,  4.81818182,  4.90909091,  5.        ,
#         5.09090909,  5.18181818,  5.27272727,  5.36363636,  5.45454545,
#         5.54545455,  5.63636364,  5.72727273,  5.81818182,  5.90909091,
#         6.        ,  6.09090909,  6.18181818,  6.27272727,  6.36363636,
#         6.45454545,  6.54545455,  6.63636364,  6.72727273,  6.81818182,
# ...

# %%
y
# Out:
# array([ 0.84147098,  0.88704699,  0.92529707,  0.95590534,  0.978619  ,
#         0.99325047,  0.99967891,  0.99785123,  0.98778253,  0.96955595,
#         0.94332203,  0.90929743,  0.86776314,  0.8190622 ,  0.76359681,
#         0.70182505,  0.63425707,  0.56145091,  0.48400786,  0.40256749,
#         0.31780241,  0.23041267,  0.14112001,  0.05066187, -0.04021468,
#        -0.1307591 , -0.22022362, -0.30786935, -0.39297247, -0.47483011,
#        -0.55276624, -0.6261372 , -0.69433703, -0.7568025 , -0.8130177 ,
#        -0.86251837, -0.9048957 , -0.93979971, -0.96694212, -0.98609877,
#        -0.99711147, -0.99988924, -0.99440916, -0.98071647, -0.95892427,
#        -0.92921254, -0.89182665, -0.84707537, -0.79532828, -0.73701276,
#        -0.67261042, -0.60265314, -0.52771868, -0.44842592, -0.36542971,
#        -0.2794155 , -0.19109366, -0.10119362, -0.01045784,  0.0803643 ,
#         0.17052273,  0.25927286,  0.34588171,  0.429634  ,  0.50983804,
# ...

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.figure(figsize=(8,2))
plt.plot(x,y , '--r')
plt.xlabel("this is my x data")
plt.ylabel("this is my y data")
plt.title("this is my sin wave graph")
plt.grid()

# %%
x = ['a', 'b' , 'c','d','e']
y = np.random.rand(5)

# %%
x
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
y
# Out:
# array([0.24000236, 0.82747012, 0.03898974, 0.80867023, 0.34454475])

# %%
plt.figure(figsize=(5,3))
plt.bar(x,y,color = '#7E10D5')
plt.xlabel("representing my cat data")
plt.ylabel("representing my num data")
plt.title("this is my bar plot")
plt.grid()

# %%
plt.figure(figsize=(5,3))
plt.barh(x,y,color = '#7E10D5')
plt.xlabel("representing my cat data")
plt.ylabel("representing my num data")
plt.title("this is my bar plot")
plt.grid()

# %%
x = [3,4,5,6,7,8]
y = [4,5,6,7,8,9]

# %%
plt.figure(figsize=(6,2))
plt.plot(x,y)

# %%
plt.figure(figsize=(6,2))
plt.scatter(x,y)

# %%
data = [1,2,3,4,5,6,5,6,6,7,7,8,8,8,8,8]

# %%
plt.figure(figsize=(6,3))
plt.hist(data,color="#700EBE")
plt.xlabel("representing uniqe val")
plt.ylabel("representing feq")
plt.title("Hist plot example")
plt.grid()
plt.savefig("test.png")

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z,c='#9327E8',alpha = .9)
plt.xlabel("my x axis")
plt.ylabel("my y axis")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z,c='#9327E8',alpha = .9)
plt.xlabel("my x axis")
plt.ylabel("my y axis")
plt.show()

# %%
x = np.linspace(0,2*np.pi,359)

# %%
y = 1 + (np.abs(np.cos(6*x)) + 2*(0.25 - np.abs(np.cos(6*x + np.pi/2))))/(2 + 8*(np.abs(np.cos(12*x + np.pi/2))))

# %%
y1 = 2 + (np.abs(np.cos(6*x)) + 2*(0.25 - np.abs(np.cos(6*x + np.pi/2))))/(2 + 8*(np.abs(np.cos(12*x + np.pi/2))))

# %%
y2 = 3 + (np.abs(np.cos(6*x)) + 2*(0.25 - np.abs(np.cos(6*x + np.pi/2))))/(2 + 8*(np.abs(np.cos(12*x + np.pi/2))))

# %%
y3 = 4 + (np.abs(np.cos(6*x)) + 2*(0.25 - np.abs(np.cos(6*x + np.pi/2))))/(2 + 8*(np.abs(np.cos(12*x + np.pi/2))))

# %%
plt.polar(x,y4)
plt.polar(x,y3)
plt.polar(x,y2)
plt.polar(x,y1)
plt.polar(x,y)
plt.show()

# %%
y5 = 1 + (np.abs(np.cos(2*x)) + 2*(0.25 - np.abs(np.cos(2*x + np.pi/2))))/(2 + 8*(np.abs(np.cos(4*x + np.pi/2))))

# %%
plt.polar(x,y5)
